# %%
import numpy as np
import params

spk_emb_dictionary = np.load(params.spk_emb_path, allow_pickle=True).item()

# %%
spk_emb_dictionary.keys()
# Out:
# dict_keys(['/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000733.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000724.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000725.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000739.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000731.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000740.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000736.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000729.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000746.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000728.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000735.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000734.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000750.wav', '/home/xingxing/COMP5214/dataset/esd/0019/Happy/test/0019_000722
# ...

# %%
emo_emb_dictionary = np.load(params.emo_emb_path, allow_pickle=True).item()

# %%
emo_emb_dictionary.keys()
# Out:
# dict_keys(['Angry', 'Happy', 'Neutral', 'Sad', 'Surprise'])

# %%
import os

base_dir = '/home/xingxing/tts/tts_ref/Speech-Backbones/GMGradTTS/logs/new_exp'

for i in range(1, 4702):
    t_path = os.path.join(base_dir, f"grad_{i}.pt")
    if i % 50 != 0 and os.path.exists(t_path):
        os.remove(t_path)
